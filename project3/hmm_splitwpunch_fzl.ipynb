# %%
# %load_ext blackcellmagic

# %% [markdown]
# ## Do pre-processing

# %%
import numpy as np
import pandas as pd
import string
from string import punctuation

# %%
def load_data():

    data_txt = open("data/shakespeare.txt")
    quatrain = []
    volta = []
    couplet = []

    Lines = data_txt.readlines()
    count = 0
    for i, line in enumerate(Lines):
        if any(char.isdigit() for char in line):
            for j in range(1, 9):
                quatrain.append(Lines[i + j][:-1])
            for j in range(9, 13):
                volta.append(Lines[i + j][:-1])
            for j in range(13, 15):
                couplet.append(Lines[i + j][:-1])
    return quatrain, volta, couplet


def load_key(includePunctuation=True):

    data_key = open("data/Syllable_dictionary.txt")
    Lines = data_key.readlines()

    key_list = []

    for i, line in enumerate(Lines):
        split_str = line.strip(punctuation).split()
        if len(split_str) == 3:
            if len(split_str[1]) == 2:
                key_list.append(
                    [split_str[0], [int(split_str[2])], int(split_str[1][1])]
                )
            elif len(split_str[2]) == 2:
                key_list.append(
                    [split_str[0], [int(split_str[1])], int(split_str[2][1])]
                )
            else:
                key_list.append(
                    [split_str[0], [int(split_str[1]), int(split_str[2])], 0]
                )

        else:
            key_list.append([split_str[0], [int(split_str[1])], 0])

    # append punctuation
    if includePunctuation == True:
        # comma
        key_list.append([",", [0], 0])
        # period
        key_list.append([".", [0], 0])
        # question
        key_list.append(["?", [0], 0])
        # colon
        key_list.append([":", [0], 0])
        # semicolon
        key_list.append([";", [0], 0])
        # exclamation mark
        key_list.append(["!", [0], 0])

    return key_list


def convert_to_nums(dataset, key_list, includePunctuation=True):
    punc_list = [",", ".", "?", ":", ";", "!"]
    word_list = [i[0] for i in key_list]
    seq_list = []
    for i in range(0, len(dataset)):
        words = dataset[i].split()
        seq = []
        for j in range(0, len(words)):
            if words[j].lower() == "th'" or words[j].lower() == "t'":
                n = word_list.index(words[j].lower())
            else:
                n = word_list.index(words[j].lower().strip(punctuation))
            seq.append(n)

            if includePunctuation == True:
                if words[j][-1] in punc_list:
                    seq.append(word_list.index(words[j][-1]))

        seq_list.append(seq)

    return seq_list


def convert_to_nums_red_keylist(dataset, key_list, includePunctuation=True):
    punc_list = [",", ".", "?", ":", ";", "!"]
    word_list = [i[0] for i in key_list]
    seq_list = []

    key_list_red = []
    used_inds = []
    for i in range(0, len(dataset)):
        words = dataset[i].split()
        seq = []
        for j in range(0, len(words)):
            if words[j].lower() == "th'" or words[j].lower() == "t'":
                n = word_list.index(words[j].lower())
            else:
                n = word_list.index(words[j].lower().strip(punctuation))
            if n not in used_inds:
                used_inds.append(n)
                key_list_red.append(key_list[n])

            seq.append(n)
            if includePunctuation == True:
                if words[j][-1] in punc_list:
                    punc_indx = word_list.index(words[j][-1])
                    seq.append(punc_indx)
                    if punc_indx not in used_inds:
                        used_inds.append(punc_indx)
                        key_list_red.append(key_list[punc_indx])
        seq_list.append(seq)

    # convert sequence to 'reduced' indices
    seq_list_red = []
    for i in range(0, len(seq_list)):
        seq_list_red_cur = []
        for j in range(0, len(seq_list[i])):
            seq_list_red_cur.append(used_inds.index(seq_list[i][j]))
        seq_list_red.append(seq_list_red_cur)

    return seq_list_red, key_list_red


def generate_sequences():
    # CALL THIS TO GENERATE THE 3 TRAINING DATASETS
    # OUTPUTS:
    # seq_list_quatrain: list of sequences corresponding to lines in the first 2 quatrains
    # seq_list_volta: list of sequences corresponding to lines in the volta
    # seq_list_couplet: list of sequences corresponding to lines in the couplet
    # key_list: list of lists containing information stored in Syllable_dictionary:
    # Each list corresponds to a word, with index 0 being the word,
    # index 1 being a list containing possible numbers of syllables, and index 2 being the number of syllables if it's
    # an end word.

    quatrain, volta, couplet = load_data()
    key_list = load_key()
    seq_list_quatrain = convert_to_nums(quatrain, key_list)
    seq_list_volta = convert_to_nums(volta, key_list)
    seq_list_couplet = convert_to_nums(couplet, key_list)
    return seq_list_quatrain, seq_list_volta, seq_list_couplet, key_list


def generate_sequences_reduced(includePunctuation=True):
    # CALL THIS TO GENERATE THE 3 TRAINING DATASETS
    # OUTPUTS:
    # seq_lists: list with 3 elements corresponding to the 3 lists of sequences
    # key_lists: list with 3 elements corresponding to the 3 associated key lists

    quatrain, volta, couplet = load_data()
    key_list = load_key(includePunctuation)

    seq_list_quatrain, key_list_quatrain = convert_to_nums_red_keylist(
        quatrain, key_list, includePunctuation
    )
    seq_list_volta, key_list_volta = convert_to_nums_red_keylist(
        volta, key_list, includePunctuation
    )
    seq_list_couplet, key_list_couplet = convert_to_nums_red_keylist(
        couplet, key_list, includePunctuation
    )

    seq_lists = [seq_list_quatrain, seq_list_volta, seq_list_couplet]
    key_lists = [key_list_quatrain, key_list_volta, key_list_couplet]
    return seq_lists, key_lists

# %% [markdown]
# ## Unsupervised HMM

# %%
import os
import re
import random
from tqdm import tqdm
import urllib.request
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from matplotlib import animation
from matplotlib.animation import FuncAnimation

# %%
class HiddenMarkovModel:
    """
    Class implementation of Hidden Markov Models.
    """

    def __init__(self, A, O):
        """
        Initializes an HMM. Assumes the following:
            - States and observations are integers starting from 0. 
            - There is a start state (see notes on A_start below). There
              is no integer associated with the start state, only
              probabilities in the vector A_start.
            - There is no end state. 
        Arguments:
            A:          Transition matrix with dimensions L x L.
                        The (i, j)^th element is the probability of
                        transitioning from state i to state j. Note that
                        this does not include the starting probabilities.
            O:          Observation matrix with dimensions L x D.
                        The (i, j)^th element is the probability of
                        emitting observation j given state i.
        Parameters:
            L:          Number of states.
            D:          Number of observations.
            
            A:          The transition matrix.
            
            O:          The observation matrix.
            
            A_start:    Starting transition probabilities. The i^th element
                        is the probability of transitioning from the start
                        state to state i. For simplicity, we assume that
                        this distribution is uniform.
        """

        self.L = len(A)
        self.D = len(O[0])
        self.A = A
        self.O = O
        self.A_start = [1.0 / self.L for _ in range(self.L)]

    def viterbi(self, x):
        """
        Uses the Viterbi algorithm to find the max probability state 
        sequence corresponding to a given input sequence.
        Arguments:
            x:          Input sequence in the form of a list of length M,
                        consisting of integers ranging from 0 to D - 1.
        Returns:
            max_seq:    Output sequence corresponding to x with the highest
                        probability.
        """

        M = len(x)  # Length of sequence.

        # The (i, j)^th elements of probs and seqs are the max probability
        # of the prefix of length i ending in state j and the prefix
        # that gives this probability, respectively.
        #
        # For instance, probs[1][0] is the probability of the prefix of
        # length 1 ending in state 0.
        probs = [[0.0 for _ in range(self.L)] for _ in range(M + 1)]
        seqs = [["" for _ in range(self.L)] for _ in range(M + 1)]

        # Calculate initial prefixes and probabilities.
        for curr in range(self.L):
            probs[1][curr] = self.A_start[curr] * self.O[curr][x[0]]
            seqs[1][curr] = str(curr)

        # Calculate best prefixes and probabilities throughout sequence.
        for t in range(2, M + 1):
            # Iterate over all possible current states.
            for curr in range(self.L):
                max_prob = float("-inf")
                max_prefix = ""

                # Iterate over all possible previous states to find one
                # that would maximize the probability of the current state.
                for prev in range(self.L):
                    curr_prob = (
                        probs[t - 1][prev] * self.A[prev][curr] * self.O[curr][x[t - 1]]
                    )

                    # Continually update max probability and prefix.
                    if curr_prob >= max_prob:
                        max_prob = curr_prob
                        max_prefix = seqs[t - 1][prev]

                # Store the max probability and prefix.
                probs[t][curr] = max_prob
                seqs[t][curr] = max_prefix + str(curr)

        # Find the index of the max probability of a sequence ending in x^M
        # and the corresponding output sequence.
        max_i = max(enumerate(probs[-1]), key=lambda x: x[1])[0]
        max_seq = seqs[-1][max_i]

        return max_seq

    def forward(self, x, normalize=False):
        """
        Uses the forward algorithm to calculate the alpha probability
        vectors corresponding to a given input sequence.
        Arguments:
            x:          Input sequence in the form of a list of length M,
                        consisting of integers ranging from 0 to D - 1.
            normalize:  Whether to normalize each set of alpha_j(i) vectors
                        at each i. This is useful to avoid underflow in
                        unsupervised learning.
        Returns:
            alphas:     Vector of alphas.
                        The (i, j)^th element of alphas is alpha_j(i),
                        i.e. the probability of observing prefix x^1:i
                        and state y^i = j.
                        e.g. alphas[1][0] corresponds to the probability
                        of observing x^1:1, i.e. the first observation,
                        given that y^1 = 0, i.e. the first state is 0.
        """

        M = len(x)  # Length of sequence.
        alphas = [[0.0 for _ in range(self.L)] for _ in range(M + 1)]

        # Note that alpha_j(0) is already correct for all j's.
        # Calculate alpha_j(1) for all j's.
        for curr in range(self.L):
            alphas[1][curr] = self.A_start[curr] * self.O[curr][x[0]]

        # Calculate alphas throughout sequence.
        for t in range(1, M):
            # Iterate over all possible current states.
            for curr in range(self.L):
                prob = 0

                # Iterate over all possible previous states to accumulate
                # the probabilities of all paths from the start state to
                # the current state.
                for prev in range(self.L):
                    prob += alphas[t][prev] * self.A[prev][curr] * self.O[curr][x[t]]

                # Store the accumulated probability.
                alphas[t + 1][curr] = prob

            if normalize:
                norm = sum(alphas[t + 1])
                for curr in range(self.L):
                    alphas[t + 1][curr] /= norm

        return alphas

    def backward(self, x, normalize=False):
        """
        Uses the backward algorithm to calculate the beta probability
        vectors corresponding to a given input sequence.
        Arguments:
            x:          Input sequence in the form of a list of length M,
                        consisting of integers ranging from 0 to D - 1.
            normalize:  Whether to normalize each set of alpha_j(i) vectors
                        at each i. This is useful to avoid underflow in
                        unsupervised learning.
        Returns:
            betas:      Vector of betas.
                        The (i, j)^th element of betas is beta_j(i), i.e.
                        the probability of observing prefix x^(i+1):M and
                        state y^i = j.
                        e.g. betas[M][0] corresponds to the probability
                        of observing x^M+1:M, i.e. no observations,
                        given that y^M = 0, i.e. the last state is 0.
        """

        M = len(x)  # Length of sequence.
        betas = [[0.0 for _ in range(self.L)] for _ in range(M + 1)]

        # Initialize initial betas.
        for curr in range(self.L):
            betas[-1][curr] = 1

        # Calculate betas throughout sequence.
        for t in range(-1, -M - 1, -1):
            # Iterate over all possible current states.
            for curr in range(self.L):
                prob = 0

                # Iterate over all possible next states to accumulate
                # the probabilities of all paths from the end state to
                # the current state.
                for nxt in range(self.L):
                    if t == -M:
                        prob += betas[t][nxt] * self.A_start[nxt] * self.O[nxt][x[t]]

                    else:
                        prob += betas[t][nxt] * self.A[curr][nxt] * self.O[nxt][x[t]]

                # Store the accumulated probability.
                betas[t - 1][curr] = prob

            if normalize:
                norm = sum(betas[t - 1])
                for curr in range(self.L):
                    betas[t - 1][curr] /= norm

        return betas

    def supervised_learning(self, X, Y):
        """
        Trains the HMM using the Maximum Likelihood closed form solutions
        for the transition and observation matrices on a labeled
        datset (X, Y). Note that this method does not return anything, but
        instead updates the attributes of the HMM object.
        Arguments:
            X:          A dataset consisting of input sequences in the form
                        of lists of variable length, consisting of integers 
                        ranging from 0 to D - 1. In other words, a list of
                        lists.
            Y:          A dataset consisting of state sequences in the form
                        of lists of variable length, consisting of integers 
                        ranging from 0 to L - 1. In other words, a list of
                        lists.
                        Note that the elements in X line up with those in Y.
        """

        # Calculate each element of A using the M-step formulas.
        for curr in range(self.L):
            for nxt in range(self.L):
                num = 0.0
                den = 0.0

                for i in range(len(X)):
                    x = X[i]
                    y = Y[i]
                    M = len(x)

                    num += len(
                        [1 for i in range(M - 1) if y[i] == curr and y[i + 1] == nxt]
                    )
                    den += len([1 for i in range(M - 1) if y[i] == curr])

                self.A[curr][nxt] = num / den

        # Calculate each element of O using the M-step formulas.
        for curr in range(self.L):
            for xt in range(self.D):
                num = 0.0
                den = 0.0

                for i in range(len(X)):
                    x = X[i]
                    y = Y[i]
                    M = len(x)

                    num += len([1 for i in range(M) if y[i] == curr and x[i] == xt])
                    den += len([1 for i in range(M) if y[i] == curr])

                self.O[curr][xt] = num / den

    def unsupervised_learning(self, X, N_iters):
        """
        Trains the HMM using the Baum-Welch algorithm on an unlabeled
        datset X. Note that this method does not return anything, but
        instead updates the attributes of the HMM object.
        Arguments:
            X:          A dataset consisting of input sequences in the form
                        of lists of length M, consisting of integers ranging
                        from 0 to D - 1. In other words, a list of lists.
            N_iters:    The number of iterations to train on.
        """

        # Note that a comment starting with 'E' refers to the fact that
        # the code under the comment is part of the E-step.

        # Similarly, a comment starting with 'M' refers to the fact that
        # the code under the comment is part of the M-step.

        for iteration in tqdm(range(1, N_iters + 1)):
            # if iteration % 10 == 0:
            #    print("Iteration: " + str(iteration))

            # Numerator and denominator for the update terms of A and O.
            A_num = [[0.0 for i in range(self.L)] for j in range(self.L)]
            O_num = [[0.0 for i in range(self.D)] for j in range(self.L)]
            A_den = [0.0 for i in range(self.L)]
            O_den = [0.0 for i in range(self.L)]

            # For each input sequence:
            for x in X:
                M = len(x)
                # Compute the alpha and beta probability vectors.
                alphas = self.forward(x, normalize=True)
                betas = self.backward(x, normalize=True)

                # E: Update the expected observation probabilities for a
                # given (x, y).
                # The i^th index is P(y^t = i, x).
                for t in range(1, M + 1):
                    P_curr = [0.0 for _ in range(self.L)]

                    for curr in range(self.L):
                        P_curr[curr] = alphas[t][curr] * betas[t][curr]

                    # Normalize the probabilities.
                    norm = sum(P_curr)
                    for curr in range(len(P_curr)):
                        P_curr[curr] /= norm

                    for curr in range(self.L):
                        if t != M:
                            A_den[curr] += P_curr[curr]
                        O_den[curr] += P_curr[curr]
                        O_num[curr][x[t - 1]] += P_curr[curr]

                # E: Update the expectedP(y^j = a, y^j+1 = b, x) for given (x, y)
                for t in range(1, M):
                    P_curr_nxt = [[0.0 for _ in range(self.L)] for _ in range(self.L)]

                    for curr in range(self.L):
                        for nxt in range(self.L):
                            P_curr_nxt[curr][nxt] = (
                                alphas[t][curr]
                                * self.A[curr][nxt]
                                * self.O[nxt][x[t]]
                                * betas[t + 1][nxt]
                            )

                    # Normalize:
                    norm = 0
                    for lst in P_curr_nxt:
                        norm += sum(lst)
                    for curr in range(self.L):
                        for nxt in range(self.L):
                            P_curr_nxt[curr][nxt] /= norm

                    # Update A_num
                    for curr in range(self.L):
                        for nxt in range(self.L):
                            A_num[curr][nxt] += P_curr_nxt[curr][nxt]

            for curr in range(self.L):
                for nxt in range(self.L):
                    self.A[curr][nxt] = A_num[curr][nxt] / A_den[curr]

            for curr in range(self.L):
                for xt in range(self.D):
                    self.O[curr][xt] = O_num[curr][xt] / O_den[curr]

    def generate_emission(self, M):
        """
        Generates an emission of length M, assuming that the starting state
        is chosen uniformly at random. 
        Arguments:
            M:          Length of the emission to generate.
        Returns:
            emission:   The randomly generated emission as a list.
            states:     The randomly generated states as a list.
        """

        emission = []
        state = random.choice(range(self.L))
        states = []

        for t in range(M):
            # Append state.
            states.append(state)

            # Sample next observation.
            rand_var = random.uniform(0, 1)
            next_obs = 0

            while rand_var > 0:
                rand_var -= self.O[state][next_obs]
                next_obs += 1

            next_obs -= 1
            emission.append(next_obs)

            # Sample next state.
            rand_var = random.uniform(0, 1)
            next_state = 0

            while rand_var > 0:
                rand_var -= self.A[state][next_state]
                next_state += 1

            next_state -= 1
            state = next_state

        return emission, states

    def probability_alphas(self, x):
        """
        Finds the maximum probability of a given input sequence using
        the forward algorithm.
        Arguments:
            x:          Input sequence in the form of a list of length M,
                        consisting of integers ranging from 0 to D - 1.
        Returns:
            prob:       Total probability that x can occur.
        """

        # Calculate alpha vectors.
        alphas = self.forward(x)

        # alpha_j(M) gives the probability that the output sequence ends
        # in j. Summing this value over all possible states j gives the
        # total probability of x paired with any output sequence, i.e. the
        # probability of x.
        prob = sum(alphas[-1])
        return prob

    def probability_betas(self, x):
        """
        Finds the maximum probability of a given input sequence using
        the backward algorithm.
        Arguments:
            x:          Input sequence in the form of a list of length M,
                        consisting of integers ranging from 0 to D - 1.
        Returns:
            prob:       Total probability that x can occur.
        """

        betas = self.backward(x)

        # beta_j(0) gives the probability of the output sequence. Summing
        # this over all states and then normalizing gives the total
        # probability of x paired with any output sequence, i.e. the
        # probability of x.
        prob = sum(
            [betas[1][k] * self.A_start[k] * self.O[k][x[0]] for k in range(self.L)]
        )

        return prob


def supervised_HMM(X, Y):
    """
    Helper function to train a supervised HMM. The function determines the
    number of unique states and observations in the given data, initializes
    the transition and observation matrices, creates the HMM, and then runs
    the training function for supervised learning.
    Arguments:
        X:          A dataset consisting of input sequences in the form
                    of lists of variable length, consisting of integers 
                    ranging from 0 to D - 1. In other words, a list of lists.
        Y:          A dataset consisting of state sequences in the form
                    of lists of variable length, consisting of integers 
                    ranging from 0 to L - 1. In other words, a list of lists.
                    Note that the elements in X line up with those in Y.
    """

    # Make a set of observations.
    observations = set()
    for x in X:
        observations |= set(x)

    # Make a set of states.
    states = set()
    for y in Y:
        states |= set(y)

    # Compute L and D.
    L = len(states)
    D = len(observations)

    # Randomly initialize and normalize matrices A and O.
    A = [[random.random() for i in range(L)] for j in range(L)]

    for i in range(len(A)):
        norm = sum(A[i])
        for j in range(len(A[i])):
            A[i][j] /= norm

    O = [[random.random() for i in range(D)] for j in range(L)]

    for i in range(len(O)):
        norm = sum(O[i])
        for j in range(len(O[i])):
            O[i][j] /= norm

    # Train an HMM with labeled data.
    HMM = HiddenMarkovModel(A, O)
    HMM.supervised_learning(X, Y)

    return HMM


def unsupervised_HMM(X, n_states, N_iters, rng=np.random.RandomState(1)):
    """
    Helper function to train an unsupervised HMM. The function determines the
    number of unique observations in the given data, initializes
    the transition and observation matrices, creates the HMM, and then runs
    the training function for unsupervised learing.
    Arguments:
        X:          A dataset consisting of input sequences in the form
                    of lists of variable length, consisting of integers 
                    ranging from 0 to D - 1. In other words, a list of lists.
        n_states:   Number of hidden states to use in training.
        
        N_iters:    The number of iterations to train on.
        rng:        The random number generator for reproducible result.
                    Default to RandomState(1).
    """

    # Make a set of observations.
    observations = set()
    for x in X:
        observations |= set(x)

    # Compute L and D.
    L = n_states
    D = len(observations)
    # print(D)

    # Randomly initialize and normalize matrices A.
    A = [[rng.random() for i in range(L)] for j in range(L)]

    for i in range(len(A)):
        norm = sum(A[i])
        for j in range(len(A[i])):
            A[i][j] /= norm

    # Randomly initialize and normalize matrix O.
    O = [[rng.random() for i in range(D)] for j in range(L)]

    for i in range(len(O)):
        norm = sum(O[i])
        for j in range(len(O[i])):
            O[i][j] /= norm

    # Train an HMM with unlabeled data.
    HMM = HiddenMarkovModel(A, O)
    HMM.unsupervised_learning(X, N_iters)

    return HMM

# %% [markdown]
# ## support functions

# %%
########################################
# CS/CNS/EE 155 2018
# Problem Set 6
#
# Author:       Andrew Kang
# Description:  Set 6 HMM helper
########################################

import re
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from matplotlib import animation
from matplotlib.animation import FuncAnimation


####################
# WORDCLOUD FUNCTIONS
####################


def mask():
    # Parameters.
    r = 128
    d = 2 * r + 1

    # Get points in a circle.
    y, x = np.ogrid[-r : d - r, -r : d - r]
    circle = x ** 2 + y ** 2 <= r ** 2

    # Create mask.
    mask = 255 * np.ones((d, d), dtype=np.uint8)
    mask[circle] = 0

    return mask


def text_to_wordcloud(text, max_words=50, title="", show=True):
    plt.close("all")

    # Generate a wordcloud image.
    wordcloud = WordCloud(
        random_state=0, max_words=max_words, background_color="white", mask=mask()
    ).generate(text)

    # Show the image.
    if show:
        plt.figure(figsize=(10, 10))
        plt.imshow(wordcloud, interpolation="bilinear")
        plt.axis("off")
        plt.title(title, fontsize=24)
        plt.show()

    return wordcloud


def states_to_wordclouds(hmm, obs_map, max_words=50, show=True):
    # Initialize.
    M = 100000
    n_states = len(hmm.A)
    obs_map_r = obs_map_reverser(obs_map)
    wordclouds = []

    # Generate a large emission.
    emission, states = hmm.generate_emission(M)

    # For each state, get a list of observations that have been emitted
    # from that state.
    obs_count = []
    for i in range(n_states):
        obs_lst = np.array(emission)[np.where(np.array(states) == i)[0]]
        obs_count.append(obs_lst)

    # For each state, convert it into a wordcloud.
    for i in range(n_states):
        obs_lst = obs_count[i]
        sentence = [obs_map_r[j] for j in obs_lst]
        sentence_str = " ".join(sentence)

        wordclouds.append(
            text_to_wordcloud(
                sentence_str, max_words=max_words, title="State %d" % i, show=show
            )
        )

    return wordclouds


####################
# HMM FUNCTIONS
####################


def parse_observations(text):
    # Convert text to dataset.
    lines = [line.split() for line in text.split("\n") if line.split()]

    obs_counter = 0
    obs = []
    obs_map = {}

    for line in lines:
        obs_elem = []

        for word in line:
            word = re.sub(r"[^\w]", "", word).lower()
            if word not in obs_map:
                # Add unique words to the observations map.
                obs_map[word] = obs_counter
                obs_counter += 1

            # Add the encoded word.
            obs_elem.append(obs_map[word])

        # Add the encoded sequence.
        obs.append(obs_elem)

    return obs, obs_map


def obs_map_reverser(obs_map):
    obs_map_r = {}

    for key in obs_map:
        obs_map_r[obs_map[key]] = key

    return obs_map_r


def gen_word_list(hmm, obs_map, n_words=100):
    # Get reverse map.
    obs_map_r = obs_map_reverser(obs_map)

    # Sample and convert sentence.
    emission, states = hmm.generate_emission(n_words)

    return [obs_map_r[i] for i in emission]


####################
# HMM VISUALIZATION FUNCTIONS
####################


def visualize_sparsities(hmm, O_max_cols=50, O_vmax=0.1):
    plt.close("all")
    plt.set_cmap("viridis")

    # Visualize sparsity of A.
    plt.imshow(hmm.A, vmax=1.0)
    plt.colorbar()
    plt.title("Sparsity of A matrix")
    plt.show()

    # Visualize parsity of O.
    plt.imshow(np.array(hmm.O)[:, :O_max_cols], vmax=O_vmax, aspect="auto")
    plt.colorbar()
    plt.title("Sparsity of O matrix")
    plt.show()


####################
# HMM ANIMATION FUNCTIONS
####################


def animate_emission(hmm, obs_map, M=8, height=12, width=12, delay=1):
    # Parameters.
    lim = 1200
    text_x_offset = 40
    text_y_offset = 80
    x_offset = 580
    y_offset = 520
    R = 420
    r = 100
    arrow_size = 20
    arrow_p1 = 0.03
    arrow_p2 = 0.02
    arrow_p3 = 0.06

    # Initialize.
    n_states = len(hmm.A)
    obs_map_r = obs_map_reverser(obs_map)
    wordclouds = states_to_wordclouds(hmm, obs_map, max_words=20, show=False)

    # Initialize plot.
    fig, ax = plt.subplots()
    fig.set_figheight(height)
    fig.set_figwidth(width)
    ax.grid("off")
    plt.axis("off")
    ax.set_xlim([0, lim])
    ax.set_ylim([0, lim])

    # Plot each wordcloud.
    for i, wordcloud in enumerate(wordclouds):
        x = x_offset + int(R * np.cos(np.pi * 2 * i / n_states))
        y = y_offset + int(R * np.sin(np.pi * 2 * i / n_states))
        ax.imshow(
            wordcloud.to_array(),
            extent=(x - r, x + r, y - r, y + r),
            aspect="auto",
            zorder=-1,
        )

    # Initialize text.
    text = ax.text(text_x_offset, lim - text_y_offset, "", fontsize=24)

    # Make the arrows.
    zorder_mult = n_states ** 2 * 100
    arrows = []
    for i in range(n_states):
        row = []
        for j in range(n_states):
            # Arrow coordinates.
            x_i = x_offset + R * np.cos(np.pi * 2 * i / n_states)
            y_i = y_offset + R * np.sin(np.pi * 2 * i / n_states)
            x_j = x_offset + R * np.cos(np.pi * 2 * j / n_states)
            y_j = y_offset + R * np.sin(np.pi * 2 * j / n_states)

            dx = x_j - x_i
            dy = y_j - y_i
            d = np.sqrt(dx ** 2 + dy ** 2)

            if i != j:
                arrow = ax.arrow(
                    x_i + (r / d + arrow_p1) * dx + arrow_p2 * dy,
                    y_i + (r / d + arrow_p1) * dy + arrow_p2 * dx,
                    (1 - 2 * r / d - arrow_p3) * dx,
                    (1 - 2 * r / d - arrow_p3) * dy,
                    color=(1 - hmm.A[i][j],) * 3,
                    head_width=arrow_size,
                    head_length=arrow_size,
                    zorder=int(hmm.A[i][j] * zorder_mult),
                )
            else:
                arrow = ax.arrow(
                    x_i,
                    y_i,
                    0,
                    0,
                    color=(1 - hmm.A[i][j],) * 3,
                    head_width=arrow_size,
                    head_length=arrow_size,
                    zorder=int(hmm.A[i][j] * zorder_mult),
                )

            row.append(arrow)
        arrows.append(row)

    emission, states = hmm.generate_emission(M)

    def animate(i):
        if i >= delay:
            i -= delay

            if i == 0:
                arrows[states[0]][states[0]].set_color("red")
            elif i == 1:
                arrows[states[0]][states[0]].set_color(
                    (1 - hmm.A[states[0]][states[0]],) * 3
                )
                arrows[states[i - 1]][states[i]].set_color("red")
            else:
                arrows[states[i - 2]][states[i - 1]].set_color(
                    (1 - hmm.A[states[i - 2]][states[i - 1]],) * 3
                )
                arrows[states[i - 1]][states[i]].set_color("red")

            # Set text.
            text.set_text(
                " ".join([obs_map_r[e] for e in emission][: i + 1]).capitalize()
            )

            return arrows + [text]

    # Animate!
    print("\nAnimating...")
    anim = FuncAnimation(fig, animate, frames=M + delay, interval=1000)

    return anim

    # honestly this function is so jank but who even fuckin cares
    # i don't even remember how or why i wrote this mess
    # no one's gonna read this
    # hey if you see this tho hmu on fb let's be friends

# %%
class Utility:
    """
    Utility for the problem files.
    """

    def __init__():
        pass

    @staticmethod
    def load_sequence(n):
        """
        Load the file 'sequence_data<n>.txt' for a given n.
        Arguments:
            n:          Sequence index.
        Returns:
            A:          The transition matrix.
            O:          The observation matrix.
            seqs:       Input sequences.
        """
        A = []
        O = []
        seqs = []

        # For each file:
        with urllib.request.urlopen(
            f"https://raw.githubusercontent.com/lakigigar/Caltech-CS155-2021/main/psets/set6/data/sequence_data{n}.txt"
        ) as f:
            # Read the parameters.
            L, D = [int(x) for x in f.readline().decode("utf-8").strip().split("\t")]

            # Read the transition matrix.
            for i in range(L):
                A.append(
                    [float(x) for x in f.readline().decode("utf-8").strip().split("\t")]
                )

            # Read the observation matrix.
            for i in range(L):
                O.append(
                    [float(x) for x in f.readline().decode("utf-8").strip().split("\t")]
                )

            # The rest of the file consists of sequences.
            while True:
                seq = f.readline().decode("utf-8").strip()
                if seq == "":
                    break
                seqs.append([int(x) for x in seq])

        return A, O, seqs

    @staticmethod
    def load_ron():
        """
        Loads the file 'ron.txt'.
        Returns:
            moods:      Sequnces of states, i.e. a list of lists.
                        Each sequence represents half a year of data.
            mood_map:   A hash map that maps each state to an integer.
            genres:     Sequences of observations, i.e. a list of lists.
                        Each sequence represents half a year of data.
            genre_map:  A hash map that maps each observation to an integer.
        """
        moods = []
        mood_map = {}
        genres = []
        genre_map = {}
        mood_counter = 0
        genre_counter = 0

        with urllib.request.urlopen(
            "https://raw.githubusercontent.com/lakigigar/Caltech-CS155-2021/main/psets/set6/data/ron.txt"
        ) as f:
            mood_seq = []
            genre_seq = []

            while True:
                line = f.readline().decode("utf-8").strip()

                if line == "" or line == "-":
                    # A half year has passed. Add the current sequence to
                    # the list of sequences.
                    moods.append(mood_seq)
                    genres.append(genre_seq)
                    # Start new sequences.
                    mood_seq = []
                    genre_seq = []

                if line == "":
                    break
                elif line == "-":
                    continue

                mood, genre = line.split()

                # Add new moods to the mood state hash map.
                if mood not in mood_map:
                    mood_map[mood] = mood_counter
                    mood_counter += 1

                mood_seq.append(mood_map[mood])

                # Add new genres to the genre observation hash map.
                if genre not in genre_map:
                    genre_map[genre] = genre_counter
                    genre_counter += 1

                # Convert the genre into an integer.
                genre_seq.append(genre_map[genre])

        return moods, mood_map, genres, genre_map

    @staticmethod
    def load_ron_hidden():
        """
        Loads the file 'ron.txt' and hides the states.
        Returns:
            genres:     The observations.
            genre_map:  A hash map that maps each observation to an integer.
        """
        moods, mood_map, genres, genre_map = Utility.load_ron()

        return genres, genre_map

# %% [markdown]
# ## load text and use pre-process keys

# %%
import pickle

# %%
text = (
    urllib.request.urlopen(
        "https://raw.githubusercontent.com/lakigigar/Caltech-CS155-2021/main/projects/project3/data/shakespeare.txt"
    )
    .read()
    .decode("utf-8")
)
wordcloud = text_to_wordcloud(text, title="shakespeare")

# %% [markdown]
# ## train unsupervised HMM for quatrain, volta, couplet

# %%
quatrain,volta,couplet = load_data()
key_list = load_key()

seq_lists,key_lists = generate_sequences_reduced()

# %%
def key_list2obs_map(key_lists):
    """Convert key_lists to the same format as obs_map"""
    obs_map_dict = {}
    hmm_names = ["quatrain", "volta", "couplet"]

    for name, key_list in zip(hmm_names, key_lists):
        obs_map = {}
        for i, k in enumerate(key_list):
            obs_map[k[0]] = i
        obs_map_dict[name] = obs_map
    return obs_map_dict

# %%
def del_empty_seq_list(seq_list):
    """Get rid of empty lists"""
    return [s for s in seq_list if len(s) != 0]

# %%
def train_3hmm(seq_lists, n_states=10, N_iters=100):
    """Train separate hmm for quatrain, volta, and couplet"""
    hmm_dict = {}
    hmm_names = ["quatrain", "volta", "couplet"]
    for name, seq_list in zip(hmm_names, seq_lists):
        seq_list = del_empty_seq_list(seq_list)
        hmm_dict[name] = unsupervised_HMM(seq_list, n_states, N_iters)
    return hmm_dict

# %%
# hmm10_dict = train_3hmm(seq_lists, n_states=10, N_iters=100)
# Out:
# 100%|██████████| 100/100 [02:26<00:00,  1.47s/it]
# 100%|██████████| 100/100 [01:15<00:00,  1.32it/s]
# 100%|██████████| 100/100 [02:16<00:00,  1.37s/it]

# %%
hmm10_500_dict = train_3hmm(seq_lists, n_states=10, N_iters=500)
# Out:
# 100%|██████████| 500/500 [11:47<00:00,  1.41s/it]
# 100%|██████████| 500/500 [05:53<00:00,  1.41it/s]
# 100%|██████████| 500/500 [03:18<00:00,  2.52it/s]

# %%
hmm10_1000_dict = train_3hmm(seq_lists, n_states=10, N_iters=1000)
# Out:
# 100%|██████████| 1000/1000 [26:16<00:00,  1.58s/it]
# 100%|██████████| 1000/1000 [13:53<00:00,  1.20it/s]
# 100%|██████████| 1000/1000 [08:15<00:00,  2.02it/s]

# %% [markdown]
# ## train unsupervised HMM as a whole (no punc)

# %%
obs, obs_map = parse_observations(text)

# %%
# HMM10 = unsupervised_HMM(obs, 10, 100)
# Out:
# 100%|██████████| 100/100 [03:36<00:00,  2.17s/it]

# %% [markdown]
# ## save and load trained HMM

# %% [markdown]
# ### save

# %%
"""with open("unsupervised_qvcwpunc_HMM_10_hidenstate.pkl", "wb") as f:
    pickle.dump(hmm10_dict, f)"""

# %%
with open("unsupervised_qvcwpunc_HMM_10_hidenstate_500_iter.pkl", "wb") as f:
    pickle.dump(hmm10_500_dict, f)

# %%
with open("unsupervised_qvcwpunc_HMM_10_hidenstate_1000_iter.pkl", "wb") as f:
    pickle.dump(hmm10_1000_dict, f)

# %%
"""with open("unsupervised_HMM_10_hidenstate.pkl", "wb") as f:
    pickle.dump(HMM10, f)"""

# %% [markdown]
# ### load

# %%
with open("unsupervised_qvcwpunc_HMM_10_hidenstate.pkl", "rb") as f:
    hmm10_100_dict = pickle.load(f)

# %%
with open("unsupervised_qvcwpunc_HMM_10_hidenstate_500_iter.pkl", "rb") as f:
    hmm10_500_dict = pickle.load(f)

# %%
with open("unsupervised_qvcwpunc_HMM_10_hidenstate_1000_iter.pkl", "rb") as f:
    hmm10_1000_dict = pickle.load(f)

# %%
with open("unsupervised_HMM_10_hidenstate.pkl", "rb") as f:
    HMM10 = pickle.load(f)

# %% [markdown]
# ## visualize A and O

# %%
def vis_hmm_dict(hmm_dict):
    """Visulize the A and O matrix for quatrain, volta, and couplet"""
    for k, v in hmm_dict.items():
        print(f"Visulize A and O for {k}")
        visualize_sparsities(v, O_max_cols=50)

# %%
visualize_sparsities(HMM10, O_max_cols=50)

# %%
vis_hmm_dict(hmm10_100_dict)
# Out:
# Visulize A and O for quatrain
# Visulize A and O for volta
# Visulize A and O for couplet

# %%
vis_hmm_dict(hmm10_500_dict)
# Out:
# Visulize A and O for quatrain
# Visulize A and O for volta
# Visulize A and O for couplet

# %%
vis_hmm_dict(hmm10_1000_dict)
# Out:
# Visulize A and O for quatrain
# Visulize A and O for volta
# Visulize A and O for couplet

# %% [markdown]
# ## generation

# %%
import itertools

# %%
def gen_aline(
    hmm, obs_map, key_list, punc_list=[",", ".", "?", ":", ";", "!"], n_words=15
):
    """"""
    aline = gen_word_list(hmm, obs_map, n_words=n_words)
    syll_numb = 0
    output_list = []
    output_sentence = ""
    for i, word in enumerate(aline):
        # don't want punc other than ( at the beginning of a sentence
        if len(output_list) == 0 and word in punc_list:
            continue
        # don't want multiple punc together
        elif len(output_list) > 0 and output_list[-1] in punc_list and word in punc_list:
            continue
        # don't want same words together
        elif len(output_list) > 0 and output_list[-1] == word:
            continue

        else:
            find_syll = [key for key in key_list if word in key]
            if len(find_syll) != 0:

                # fix I in the middle of the sentence
                if word == "i":
                    word = "I"

                for possible_syll in find_syll[0][1]:
                    if (
                        syll_numb + possible_syll < 10
                        and syll_numb + find_syll[0][2] < 10
                    ):
                        syll_numb += possible_syll
                        output_list.append(word)
                        break

                    elif syll_numb + possible_syll == 10 and find_syll[0][2] == 0:
                        syll_numb += possible_syll
                        output_list.append(word)
                        if i < len(aline) - 1:
                            next_letter = aline[i + 1]
                            if word not in punc_list and next_letter in punc_list:
                                output_list.append(next_letter)
                        break

                    elif syll_numb + find_syll[0][2] == 10 and find_syll[0][2] != 0:
                        syll_numb += find_syll[0][2]
                        output_list.append(word)
                        if i < len(aline) - 1:
                            next_letter = aline[i + 1]
                            if next_letter in punc_list:
                                output_list.append(next_letter)
                        break

    return syll_numb, output_list

# %%
def gen_poem(hmm, obs_map, key_list, n_words=15):
    """Generate the 14 lines"""
    poem = [None] * 14
    line_count = 0
    while line_count < 14:
        syll_numb, output_list = gen_aline(hmm, obs_map, key_list, n_words=n_words)
        if syll_numb == 10:
            poem[line_count] = " ".join(output_list).capitalize()
            line_count = line_count + 1

    return poem

# %%
def print_poem(poem):
    """Print the poem with given format with non-optimized punctuations"""
    for i, p in enumerate(poem[:-2]):
        if (i + 1) % 4 == 0:
            print(p + ".")
        else:
            print(p + ",")

    print("  " + poem[-2] + ",")
    print("  " + poem[-1] + ".")

# %%
def gen_qvc(
    hmm_dict,
    obs_map_dict,
    key_lists,
    qvc,
    punc_list=[",", ".", "?", ":", ";", "!"],
    end_punc_list=[".", "?"],
    n_words=15,
):
    """Generate 4 lines of quatrain or volta or 2 lines of couplet"""
    if qvc == "couplet":
        line_needed = 2
    else:
        line_needed = 4

    poem_qcv = [None] * line_needed
    line_count = 0
    while line_count < line_needed:
        syll_numb, output_list = gen_aline(
            hmm_dict[qvc], obs_map_dict[qvc], key_lists[0], n_words=12
        )
        if syll_numb == 10:
            output_sentence = ""
            for i, word in enumerate(output_list):
                if i == 0:
                    output_sentence += word.capitalize()
                elif word in punc_list:
                    output_sentence += word
                elif i > 0 and output_list[i - 1] in end_punc_list:
                    output_sentence = output_sentence + " " + word.capitalize()
                else:
                    output_sentence = output_sentence + " " + word
            poem_qcv[line_count] = output_sentence
            line_count = line_count + 1

    return poem_qcv

# %%
def comb_qvc(hmm_dict, obs_map_dict, key_lists):
    """Combine generated qvc"""
    poem = [None]*4
    poem[0] = gen_qvc(hmm_dict, obs_map_dict, key_lists, "quatrain")
    poem[1] = gen_qvc(hmm_dict, obs_map_dict, key_lists, "quatrain")
    poem[2] = gen_qvc(hmm_dict, obs_map_dict, key_lists, "volta")
    poem[3] = gen_qvc(hmm_dict, obs_map_dict, key_lists, "couplet")
    return list(itertools.chain.from_iterable(poem))

# %%
def print_qvc(poem):
    """Print the poem in qvc order with given format"""
    for i, p in enumerate(poem[:-2]):
        print(p)

    print("  " + poem[-2])
    print("  " + poem[-1])
    print("\n")

# %%
obs_map_dict = key_list2obs_map(key_lists)

# %%
print_qvc(comb_qvc(hmm10_500_dict, obs_map_dict, key_lists))
# Out:
# Love. Brought compare of deceivest say best.
# Very flame is in love increase and struck
# As the of once many's immortal faults,
# That love for self-love live worthy, boast in.
# And for as full doth moment willingly,
# All expense all thy upon the time's fell
# Worth's minds be whence that thinking thou confounds
# You, seen shines whose for that to yet a of
# Those to this bitter than thy o face those
# Our canst found is gainst thy time's nature for
# Infection, to he, more sweet beauty's with
# Rich were or the vassal the away death
#   Mine I with that well watch wealth to more I
#   Whose can part look my. Thou in me and you

# %%
for i in range(10):
    print_qvc(comb_qvc(hmm10_500_dict, obs_map_dict, key_lists))
# Out:
# Exchanged, is't that worth, is knowing saw out
# And in own fair full, counted my heart dost
# Their my love december's was us the time.
# Come is self and to short fleeting sacred,
# By groan haste the there. Again, objects doth
# I particulars whereto wherein spirit
# Hath without me shall but flies is predict
# Bloody gentle humble gives not one, can
# Keeps fame have, your what knows eternal, thy
# Decay mend to, return still me strength time
# For of: cross again, looks no and my the
# Anew what it in sea very and should.
#   Lost, their tongue him times beauty love have, take
#   Of his thy is gain not in my me, young
#
#
# Spend bring hundred which in say praise, art's, seen,
# Quill doth bars beside moment, if utmost
# Bareness dry felt I; my white yet, it of
# When canker hadst that see tis though thou to
# Filching nymphs, dispatch, but his sunken fair
# Learned forbid, not thy idle, nor those I
# Scarcely mine ear? Reason: thy beautiful
# What thou deeds second with thoughts name dost sit,
# Of his your thy I all looks. Themselves of
# Sad was shall rehearse sometime newer of
# When thy why who mistress face make knowledge
# Ground to, o from made world base mend gave it
#   To used I may in eat eyes happy I,
#   They with say love must to yours ill. Thou fool
#
#
# Thought lines is my make rage unused and yet
# Parts for your thing all thy epitaph is
# Sweet'st yet is art high, rhyme painted the youth
# Think betray do more true, I which he it
# Shames and now of by world eyes, is't can light's
# Weary ornament. Comfort when I her
# The verse and flowers should not love shines and of
# Motion contented day's thou of sweet for,
# Divine gentle same acquaintance this thy
# Time's than will fair, year of this more, like give
# Ruined a it what thy thee pride but for.
# From wilt husbandry she my unkind thus,
#   On that now of knows which, yet and teach too
#   And as looks, for think yet with days have slight
#
#
# The love no hand, tender so grows alone
# Dressed in of strange banquet thine offence to,
# Without, cruel, largess nor, thou sometime,
# That far with yellow you, self-killed. Than when
# Every hot his might sail devouring voice,
# Homage on thy tongue's, and the songs friend muse
# In of thy offence to as and doth but
# And above eye gives of thee prime good head,
# And time's that depart still self such that bearing
# Nor is much, then my change edge hour to thy
# For fortune's, like so thou she fortify
# To all proud of. Guest thou at worse you seest
#   You were the you doth. Canker, I wilt, I
#   Dead till thou fear this strongly from beauty's
#
#
# Against saw queen whose, love. Proud-pied mourn my
# Nor lips much of flower burthen the their this
# I fire, but condemned for thy comfort
# Profaned less reason remove my, and it
# Make dear nature, wombs what I slow for wound
# Wood's builded banquet forfeit not quick I
# Although sovereign love. Halt, to marble might,
# But winter's return love-god the earth, of
# A that in those. Sweetly of thy steal thee
# Thee nor I not the they sing for you love
# But the must in every bear my a that
# Thou in stars was in unfathered, thy thou
#   Yours given and store. In am better right thing
#   When beauty must wish remove that still, dumb
#
#
# Than thou soon dost her riches and broils wide:
# Intend let survive beguile or a so
# For own haste the delighted false. Be shall,
# Have lips see the dear your o'erlook vanished
# Knows the way and thou a you were or from
# And away thou cheap thoughts true sight, and to
# Thy into place, within desire a prey
# Receipt spent and, o'ercharged being posting doth,
# Dial took, worst, see, seemed of and as or
# Rest assured to, to for many pen best:
# And soon thou that merit their thy heart thy
# Steal all break their thoughts live had thy from your
#   Tears my sad foul to my me father, such
#   The, more thou, he thine so of till these think
#
#
# Sold sunken, majesty stol'n to my slave
# Crave bright forth hurt, and to true disgrace cure:
# Ere in woman's thy riches so not be,
# Bring our hand why say well that cloud or of
# And is the savage, directed hath hawks,
# Long find depend and? In another, bent
# Work self? Die no, and having his feeling
# I when are swift, if the refuse supposed
# When which thou a that my, merit in, ill
# Sad but to the but best almost upon
# Of waste because than let in those them should
# When a live only that kept strong state this
#   With even thy flatter, pay. Thou show purpose
#   Thee unless do want my else. Them, another
#
#
# Praise or upon abide. Be. To crooked
# So hath world's love hath body's, one is me
# To ornament for invention decay,
# Do that how do me she spheres base compeers
# As lie: three how methinks as me, not but
# When hell wife still. Still join every this times
# Which as the long-lived be grounded fleece my
# More sum, melancholy which are shall be,
# By miles it audit hath from pass bath be
# Canst unused see made the in will, forth thou
# Love lively have back your thine cannot poor,
# Face his those, mind his let one outlive the
#   Old winter's answer knows love and this that,
#   Eyes. Thy thee but leave and my enough of
#
#
# Truly of fears, a sad thou eye what should
# His my give written concealed and to that
# Love not could wherein beauty's day hearts. Own
# Past his from light or in of spot truths of
# Away make lofty cannot as sweet I,
# On hate is augurs loves and of a with
# Tell wasteful precious I not that drop as
# Sun, convertest, if the love, away and!
# Whom this, them excuse change you summer be
# Times but desire of, shall thee have pride state
# Ill. The sense of is are thou of doth no
# I, with for to of, and love for to all
#   Thy inward you general, thee this is near
#   Shows, purpose. Which that it outward bath and
#
#
# My waste told, away made, age and cost time
# For deep thy of with keen is, loving his
# Thou clock of did compare, to deserts, thoughts
# That I must that limits I I thou why
# Fawn: me beauteous, lies buds scarlet rehearse,
# Argument disgrace: or have alien, the,
# Making be light, or far the publish poor
# Am reason but do that whereto grace green?
# Therefore from controlling my thoughts his, so
# And mine with, sake thy excuse? Effect they
# And have be but whom have hell stay thy their,
# Truth, self sound me and whilst thy times thou quite
#   Away o thy so often and you art
#   Care men says my shadow I beauty's thy

# %%
for i in range(10):
    print_qvc(comb_qvc(hmm10_1000_dict, obs_map_dict, key_lists))
# Out:
# Gone in dressed forgotten a pride foul worth
# For curse, if art in time's lascivious tell,
# Up, wishing my canst to excuse to take;
# Trust eased unkind face your and, excusing
# Thou, hence rare batt'ring presage I that wrong
# Beast all, so doth brightness of that: that all
# If his not amiss nature I blame have,
# Shall in are marigold before, show eyes,
# Thee unused: more have thine his argument.
# Help more vainly expressed, cross, and many their.
# On esteem for mourn I to this, and I
# And of better how say but no, did not,
#   Show for I you, thou for elsewhere I. Both
#   Thereby, wretched and heart's hold, scorn thy love
#
#
# You I thee hang deep of although see earth,
# The. To fair me love treasure life my way
# Semblance jump the. Took of, of, presage sharp'st
# Youth feed'st addition proudly smell thou? Which
# I shall acquainted from fair complexion:
# Beauty, but intermixed but thee: touches,
# Love less thing betray of masked me nature's
# Unswept hungry told a return, it by?
# She rank my shall though mine benefit mad
# She water now honour from it so well,
# Both for living this, ornament, prepare
# Lose within of swift what day, I were art
#   And well, so thought dead verse and love born this
#   Thee still when in have so he unkind me.
#
#
# His for conspire; alone although winged
# Age's thee reason, if, possessed is love
# Felt that's to thy their muse, stop to of, can
# Truth? Best, deem mountain to eternity
# Or have it give cancelled entombed the,
# Do in bounteous wrackful when my find thanks
# To on female of prone height of should hath
# Above clouds joy, and age lip and held cheeks,
# For though he I as my absent summer,
# Fingers suspect from would brand the what be,
# Mind live beauty, the pass and thee hath of
# When mansion merit looked thinking, love life:
#   Long, or all in I name die my fears might
#   Please and not inward in sin babe glad no
#
#
# How sicken alone my blessing her boughs,
# Over-plus bright, roses moan I nor these,
# And stays men spirit shall thy blind thy are, of
# How sweet thy if and are from cancelled cease,
# I in and send me tongue. Part, write is hold
# In that of for or behold hidden earth
# Hungry painting great I a to in doth
# My seek autumn, faith brief is: a abide
# Alters he eyes fault now thinking in more
# Thy a first, my will made, the words themselves
# Very all many part to abuse, and am
# Time the new, measure sometime which, inward
#   I their she and leads her. My thou doth I
#   Hence, for it to where and so sit, three ah
#
#
# Music would active my boot the sun's, bear,
# Creatures love merchandized, should time, strangely:
# And than me doth your self bear'st ornament
# Mend, if springs to admitted task to seen,
# Big beauties me for with hoisted, not the.
# Themselves as with kingdom of be, joy of
# And of towards a virtuous sing is so, call
# Alone mind pine so goest sensual my from,
# Of in thee to use out it sweet with those
# Is, I and but live account with thy day
# Was have rich say within be thee numbers
# And unfathered the but done oaths why whilst
#   My dost breed full and is to I and be
#   Nothing pain had have by rare, it but eyes
#
#
# Knowledge to? Do, not although her can time
# Day am change, beauty as should to touched a
# Treasure babe autumn, can with over-plus
# Love's you never, surety-like, of guest love's
# Thine art, falsely for be fairest eyes when
# Sweetness of pursuit of and all my till
# Be you love thou to as thee respose not,
# The thy form if speak I the what love me
# Hand to I and wilt the old pride, shame doth
# No rage many up sight decay, thou soul's be
# Holy in new. His turns of he time's many
# Leap knows leave, my blessed pass to ten, the
#   Mine be but image lo to but. Thou verse
#   Cannot me, if and before, of that. And
#
#
# It might, foul tongues wiry I mine, every:
# Reason wand'ring from elder against that,
# Hours shun deceased aid know self's my yours
# Die none surety-like to is, the sinful
# Had as their what a over-goes self lays,
# Do, but, decays delight writ? To under
# Substance what tops a more? More, time, in it
# That whom willingly: fuel, but what they fast
# The lie more of shall name to which when if
# There birth sweet: others born being and than no
# Where beauty too the youth both more. As which
# Hours better this, thy that write, my thence his
#   Thy die grow with and their live in your have
#   Me doth to life loss my more joy praise weeds
#
#
# Stay mind can inherit as star where should:
# With their beauties pen know a to could their,
# Subject is temptation my, warrantise,
# Since be thy he summer's to am lords? Use
# And, bear'st love art, dost harmful my control
# Usurer shalt thou saint careful ah make
# It if came wail of sepulchres, one finds
# To: I and then a goddess saw objects
# Doth, your the art do self I tongue-tied to
# And not love thy time's such o let have I
# Up eternal tomb truth show, their thee, truth
# What potions and who and self doth and thou
#   Have since thus so, so deeds, and if is thee
#   And beauty winter's thee, that me for to
#
#
# Thus, thy increasing show your self wit us
# Night some betraying his merit was why,
# Fixed golden give he time is be thou slide,
# To with dignified: heart quicker with, my
# Of. Live, view keeps wear dear art doth stealing
# Argument are I, death can and, of for
# Nay that banquet thy by wills will on quite
# Death's of with, all jump how fairest to in
# Thence prove from self measure and or in of
# Defect be of one haply you waste see
# Are sweet thy where too beauty art, so see,
# Better lose why age not what let I who
#   Yet still you fear, their tyrants unkind it
#   In my heaven so be others strength ill writ,
#
#
# Thou, so sportive, would so a from soul face
# What's to in thee from. Have befits none love
# Thoughts black: less ill burning and of by thing,
# If wanting to-morrow his and waste, rotten,
# Need not merchandized live no breach, is he
# Self too, dost my ripe fairing on brav'ry
# May, do thine might stamped overthrow that in
# Why from this: two tired shaken not, to and
# Pleasure to two, bloody my babe? Thy back
# Be his, of neglect there buried, then could
# Beauty pride, by on so, now will so the
# Best in thee in; and no the those find the
#   Are so world and, thy you, on thence you had
#   Me lov'st and thee yours of I be, my such

# %%
for i in range(10):
    print_qvc(comb_qvc(hmm10_1000_dict, obs_map_dict, key_lists))
# Out:
# Triumph his slow treasure precious spirit even
# No unless not nor day for half with loved
# The lords complexion say you beauty least
# And is will you the I when not what air
# Return in and shall wit knowledge! bore of
# Th' whilst eye then reigns compare with face but stirred?
# Toil is which crowned is have it all power have
# Of control more wide horse me, single hot
# Depart, of your esteem help, do please change
# So to believe shade me life sweet, for it
# This air weed life up, for only sad, and
# Me of than believe tears my they, what have
#   This, live I, die she gross and weep this no
#   She if born, time's be and days of yet whose
#
#
# How and entombed gainst. Loved, but speed and
# Thou for alone do tongue? Thrust though yet some
# Beauty come in my a to that as story,
# Loss my among bareness favour removed
# Thou is word they that whilst son, thy shall on
# Of aright whose self placed tongue-tied, hands.
# Seeming and, spirit alone verse shady much
# Sway'st madding you proceed it light over
# Self o what wherefore though in thy my true
# Or I public which back lose time, it the
# In did self thee, beauty's hours masked lose not
# Thus haply the must most muse in heart, most
#   When cold be. Becomes, if seeming love and
#   Woe, much I despite heart thee learning by
#
#
# My ever-fixed show, eye whereupon
# Do thou, oft dead looks that virtue of those,
# It thee, every be are which to have yet
# Vows with and art love crown the each check, grow
# Yield you livery with a weakens a
# One am applying heart is as the eyes
# Now thee all love far for temperate mine
# Thou heart to thee sight thee statues, of blood,
# Forsake a my tend. Will, tie mind and yet
# How be doth palate cause to palate? Birth
# Place, my done hour thy fair it beauty to
# Nor is both of sake, my self cannot shall
#   It me I to for when fear in that his
#   Show, think and man in my makes kings. I love
#
#
# Phoenix of april his in his praise maid,
# Stay lays, abuse how buds that I write never
# So surety-like, one will not know thou! makes
# But, with not light truth thee of found am like
# But my set bright but control golden a,
# The time soul forsake self, love cures thy, or
# Never, that key is to should and alters?
# Will by strength finds treasure second in sounds
# From is, of delight, respect sweet nor me
# Thy woman better of truth, one grief this
# Lend, to I shame in them are the fair out
# Picture more hand, to these place, and frailties
#   A thou muse and me, she away I that
#   I self any give all heart it him so
#
#
# With face star eyes appear, no fire I such
# He fair them eyes water, mistress and foul,
# To prove after born restore self praise the
# Stone hath yet in time's climbed by, honest why,
# Call, what how with nature bar, might hatred
# For cry golden quick suffers gentle of,
# Windows the and thou were should of simple
# More praises teeth upon thee heart doth eye,
# Thou present, another lips time the and,
# Hide spur, and love it since so thy fair, I
# She, a posterity. Be eyes, pride my,
# For works issue far false men's, proud my his
#   Might before the shows, beauty as love's my,
#   Thy thence, or best will me son me not thy
#
#
# Ever-fixed such: and his, triumph was
# Far book of: others is self vowed that treasure
# Your beauty: eye unfathered made sweetly,
# To find, to, suspect lies in my the loves
# I, I: view, trust in all-eating mourners
# And invention and teeth you this: directed
# Receiv'st never silvered mind decayed, two:
# Two all to my bear cause, pine, manners dull
# So seemed in praise may before, to your me
# Cross present be he not that yet youth of
# And that me can the shadow motion: their,
# On you and then and my wherefore I with
#   Days things women's gone wrong then art lov'st what,
#   None on beauty hast told to new be so
#
#
# Gone have or compare it left for to the
# She subdued well return hate, deeds, where, though
# Vilest that, were base, our that more return:
# Little action with in lease have tender
# Thy backward still eye eyes moon sounds although
# Stay you but this more of begins honey
# Which? So mayst love me but beauty: love never
# Oppressed my, painter's thou, art to scandal,
# Decay, and not it the thee, use me live
# State, though the be. In the will so she in
# And what any and dare have be thy a
# Hold and no loss, but much from if more doth
#   Their is. That woe heart sick they see of swear
#   Love's days this water. Not with more stand are
#
#
# Self excel alteration of sounds, of,
# All cover that form: in slave like love's give
# Bestow'st? Brave lack never, weeds, all no tomb
# Yet of this make my brave brightness should where.
# Love that the, and flies taught acquaintance that
# In second, issue worth sepulchres would,
# Will have brain bring desire whose the subject.
# Took thy to besiege full kingdom? Eye, where
# Eyes despised words could eye eyes at not,
# Was say thee star of heaven. In thou and sets
# The but and true love summer than dust at
# Mine o shall speak for of me: and do a
#   A by, did, look and now and tongues thy right
#   Men. Near care and in ill lov'st sweet let your,
#
#
# I come was princes intend loss upon
# So thou, steal in worth mind deserves walls better
# Say the honour the credit earth your. Fell,
# But mind thou owners the you before need'st
# Mind as a successive out thine murd'rous,
# Self, poor th' uttering goddess no, should fleece nor
# Stay is but although of my thy, how, fair
# Thus give me not upon desired as:
# In my ten, my which all so but the base
# Upon where find place her state even is that,
# Not their, one thou dear with of picture, do
# Not as of desert my men's rich tis were
#   Then, loving gives to bad that to my to
#   Thief my life but smell bear is but I theirs
#
#
# Change I I will false small, subtleties and,
# To self died predict better form by name,
# Of ear: then my a the of a outcast,
# On my therefore, and alone didst doth the
# Oaths best but steepy love and love compare,
# It of my to as that she not of making
# A spirit that newer can verse love and, dimmed
# I number return should, hand rondure leaves
# How love of leisure well whether days for tongue,
# Now be his without self, and they those doth
# When lose with my life, and april, a in
# Done he with be delight of and prepare
#   My verse let thou but, that I faults I who
#   Single thee their thou in what have eyes my

# %%
for i in range(10):
    print_qvc(comb_qvc(hmm10_1000_dict, obs_map_dict, key_lists))
# Out:
# Least, is intermixed see have true survey,
# Love is sourly maiden tresses, do in
# See and nor night dear then or took dispraise
# Do say dear thus which forsake, not and a
# Mine showers and but which do losing with did
# I of my, days, mine general not that and
# The fierce that, all so whate'er, gazing far
# Assistance works face still woman's as that
# Desert his should mourners from thy high. Brought,
# My great lie, knows world and were not present.
# Was lest merit like was which but from ah
# When mine jewel of deceived. For make,
#   To thou. Summer's but, beauty's that you, my
#   Knows, shall out I men, crime and canker that
#
#
# More therefore dost, if, sea's it against sweet
# Since not making it will my bond the bare
# Trust obsequious life! of head change own of
# Nor my visage they on men's alone now.
# I commits another it gay give of
# Sight dear shames that vial it humour no
# Rider angel when thy asleep, whom this,
# Huge not true year against much thing sinful
# And sin of, common bears bitterness with
# Let of let alone good in all still my
# Many true are I eyes I it make then let
# Place. To will I sea my live show, of great
#   Of with of teach beloved used, thou to for
#   As you no. Fond love ne'er more being not lose
#
#
# Head when sweet me from old, what men thy my
# Are some distilled freedom deep I but if
# Love self thy long their married prime love that,
# Not left corrupting these my off how the
# Enjoyed better: not cannot no, a make
# In, many damasked the. Sometime, on I that
# Beauteous of so pleasure and summer's make
# Doth I in excellence, committed thou
# Mad how have I is all thy willing my
# Why this answer shall love, what others doth,
# Is thy deeds, that then hope, honour words, or
# Muse passed is who know truth that have beauty
#   Th' flattery of my self to thy love yet got
#   Yet outward that love in your with him but
#
#
# Words creep the his of affords her broke should
# Fault as hanging shop do love, ever love
# Guilty: age, fair more made, advised, fortune's
# Dearths and of I counterfeit on wind her
# Have strangle? Verse beauty you the best thee,
# Against my fill heart conspire? Sick, art in.
# Old unset borrowed sweet sight stelled rondure
# In a legacy no, not out another,
# Desert thought shape where thou shadow, but thy
# Youth, where knowing or let me I therein.
# Is my sake ever there acquaintance but
# All love but he they eyes and as vassal
#   Mine masked thee your once none fear one will when
#   Thy love, and thinks wretched and by all forth,
#
#
# Not in fair me whereto his this prime think,
# Qualify none amiss and beauty his
# In days of: kind, masonry, fearfully
# In your of: rolling takes lusty lovely,
# New of and new her masonry in night,
# Why high eyes on the treasure, was truth of
# Roses are tie my, pride silent lame dearly
# Would thy impression unseen might if, of,
# Away, when what the loss, take hath boast, that
# Another thee a care, art. Happy deep
# Rich can me than, I believe forsake than
# Must assured ever skill. In were lie
#   Sweet when more being thy though I still as still
#   But either's I pity but their thou thought,
#
#
# Unseen looks the weight beauty's gives my to
# Beauty's dull why forbid is I statues,
# First me thy increasing in. To in not,
# Can as flies, dost now by with I but their,
# Thus so force, should cold, thine think mine of was
# Abundance amis to alone me. Other,
# Sun's. In broke, expense sick reeks siren sick
# On thy white, love-kindling, roses an look
# Three is leaves shall thee, holy o are they
# Clear of done, from spent, thy deceived mend
# Other will the sinful. Bail, their thought worth
# I old gave me beauty, therefore happy.
#   For rich. And for weeds with and my alone
#   True my black for black curse store, remember
#
#
# They for excellence song not bones my eye,
# And frame it strength painted, hours name, brow gift
# Way kiss the so summer's with. Eyes, show date
# Durst while time thee do nay what their so quick,
# Field delight seem one cannot hath: maiden,
# Keeps powers to weep an her an roses and.
# Excuse is lest clock glazed do: absence,
# Love's which may sail I that upon this proved,
# Let I you and foul of my day the great
# His groan wasteful doth vex the catch thy thou
# I true grow'st, than not the wrong hold woe eyes
# I a your fingers or mend a him nor
#   Life, if praises unkind now praise brings, so.
#   For, with to every, my winter's I twain,
#
#
# Them do. Face find you lifts those dost my thou
# Left home side endless, thine yet, the: thorns in
# To on thy power they am mars to hide how?
# Spread moan plight mightier, rude and wish it, gone,
# Having: as thee sing kept do embassage,
# Thine nor my why or mother foes you stamped
# Pity-wanting to their. You, should is I,
# Action! none nay to this fill, with he, to
# Each for not note, ever poor, my heaven of
# Be inward in losing lies thy of thy
# Side can give tell ever in gentle passed,
# Will heart's thou use, all outlive the with not
#   Elsewhere lo sun and heir in for him, young
#   Love, this days: you I me be matter am
#
#
# When stone, look to both your, by flame not cruel
# Niggard thou life glass live, every eye, to
# Cannot is lying and will, travel doth
# Adjunct a shorn his, which of two, thought thine
# Princes mine a will the. Still false, would and
# Betray all the beauty's I eyes so then
# Which of your, now my thy that the his and
# Thoughts lap hide past eyes might I he beauty's,
# And into made, hide live thy thoughts pass on
# Own that. Possessing husband to doth: mad
# In tongue decay doth by please give both with
# Cannot thou both are, the his muse I a
#   Sight but this thou, shun and leave for wish too
#   State love her are and thou whose see thy see
#
#
# Against very that coming my say. Lend,
# World thy desert friend thy eye thine cannot
# Note, which trespass store, minutes an of life:
# To so and wide the now sheaves waves, spirit, still
# To thy sins I away speed thine and: he
# As care worms: have your besmeared make those head
# To devise confine outward mine: confounds
# Vanished doth to sing warmed, can might all a
# Thou where tis his see before of so I,
# Ay my deeds that my the than and to doth
# Me are the blood, and by with old shame my
# Of heart were in to beauty being a I
#   Thou, for thou adjunct thy the if can art
#   And she back seek that your all that deeds I

# %%
for i in range(10):
    print_qvc(comb_qvc(hmm10_1000_dict, obs_map_dict, key_lists))
# Out:
# Side: days the of her of heart shadow one
# Bones mock strive thee worms though beauty so wealth,
# The lascivious face grew thy maiden and,
# Fair what? Thou taste, now by augurs trifles
# Lov'st the; wrackful, love, stay and painting you
# Set nor canker which hearts spirit sum out new,
# Shake to tongues worth, me muse defects, repose
# Peace, did eyes journey cease dearest reproach,
# Well I friend may thee, by tattered love, the
# Worth art? Their folly, nor your mourn may how
# Be, and upon thy face to so that in.
# Out make, altered are child or of assured
#   More pity complexion let men beauty's
#   Lived which new self ever nor. So show, love
#
#
# And bareness as sourly a world true time,
# Love woe laid, then I such my do see line,
# Physician have called that saturn the case.
# My by and thou, aught skill shall most jewels
# Under than but those hours thou, skill to, fill
# Will me now therefore doth ruining my
# One every a three her burthen. Summers
# Once to woos a again sum endured spite
# Better bad, sour to what the world's gilded
# Mad hours, so decay are their rest, of one
# Bring besiege this, it mine which now even for
# Sin all not in not being the that and the
#   Lived must writ be flowers therefore, that behold,
#   By but let and picture in art mind in
#
#
# My up-locked I number might, true he
# Not, be pitiful ever beauty year
# Of loveliness my, see thrice, nor approve
# I wish and but that power, thee things and: a
# Some doth eyes his, decrees, imitate stand
# Bait faults gross thy with love have and then when
# His be my, maturity bestow'st with,
# I? Chide, another decays, surety-like,
# And methinks the decay, contracted love
# Memory time's a when so death he up
# Through thy, prepare heart's be my see, nor time
# Even and many, if still base, be that look place
#   And unused bright, in is thou, nothing go
#   Thy give I distilled yet time this be that
#
#
# Shine, honour as gentle a odour skill,
# Can death's to spot my men sacred their, my
# And if and if these I where not mine if?
# Desire art moon bars did fever forget'st,
# Merchandized then. As; burn was but look my
# A although dreams of my, tongue and, my love
# When fair basest stand steal the of such what
# I, thee war, I such mountain smell doth hides?
# Me addition to not to brow my tis
# For than my praise, I to the had of mind
# It a strong, grace be life than to gentle
# Are by you all am. And prize be is are
#   That you heart's read fine am than see sweet this
#   Which thou to read general evil world's my.
#
#
# Nothing his death's o'er-green thy and, decay,
# Perfumed, no thee thou, summer's with mine flowers,
# My he my; glass, give in argument and
# Your, and picture's in me of from the bore
# Me keep, what that whilst flowers sweet, poor with up
# Many endless his, own in fashion, days false
# Into yet which pen thy whose in very
# So vial each lend could outward glazed
# And although a it to thou the sick out,
# By his to with cannot do my face thou,
# The beauty to these self of doth in foot
# And to the end, thy weary, mend will air
#   Elements to were praise, thee and eyes sick,
#   Prove must call in I thus both I skill may,
#
#
# Love songs qualify, feathered whom they give,
# It am and have love themselves majesty,
# Sway thy that upon no time more gilding
# Heaven revenge from I nor world how the with,
# Need crowned, from translated heart to their sea
# From world blow all roses and mock are grown,
# But thou dost survive me, night scaped giving,
# Pay stamp love wood, self thy they largess keep.
# His of state you I past then on not fair,
# And no with to self make, and much no are
# Walls my me steel found I be my day, of
# To glory truth such lines sight of they you.
#   In such give shows, kill, but thine think my thought
#   That she hast of be not, things my is sweet
#
#
# For did will, lacking not? Never, should so
# Clouds maiden, age peace out th' blushing thine reeks
# Esteemed, must me heart, who and make a is
# Year, all their motion say you canopy,
# Thunder his, the. Reeks in father death's all,
# Date faults with sweet and no knows. Black away
# I not give true of you jump half stone as,
# Loan none, so then increase please was behold
# That by the this unused friend, thou made hate
# The be than the to the reason me to,
# Men, turned nought on and. Nor ornament doth
# Proved all almost back thy my of that and,
#   But yet that love, skill eyes art and of as
#   Do most love no thou. Might doth thou a be
#
#
# Of youthful and that as are steal, declines
# Is't do my sluttish beauty was her show
# And, wailing thus on me find nor winds spirit
# Golden honouring confounds is given when,
# Crowned it deeds, gazing as their the shine good
# My o the not dead, making thy second
# As the which sight age purging. Wires: finds a
# Farewell her praise being own were report and.
# Frailties her his make with tie. What fair thou
# In the no me winter's state where it lie,
# Which thou I oaths him my heart so state? Thy
# Ever moving truth, whom the present, thee,
#   Your. Says. That be thee know thee fame them live
#   Large play but, and never heaven that, despite
#
#
# Accident, thou true strange, do be are of
# Hath increase how, breath favourites his the,
# Under but against for every fair praise
# Is, love first-born is men but express thee
# That long, comfort hand our devour of sums.
# Fled, to hold simple task I have needs which?
# Thou blessing thou, strong such you will torture
# Jealousy wills and wrong behind, song and,
# Men follow and woe losing lies in spent,
# The and his of thought: from now flattery
# Or sound truth time thou self, thou unused thoughts,
# Strong pride o'er he new, that losing and he
#   On or worse a glad on to and for not,
#   Leaves and now be, him of is answer send
#
#
# Me art to with his lovely for this write
# That to then to wombs beauty achieve, if
# Interest plods know cruel worms love all their
# That need then barren dost why dost! thy how
# The blind. Eye blesses, sight happy the heart
# Account. Your stain I methinks betray my
# It dry the doth which goes things that, and then
# Not and heart but wrongs thee pour'st foul who why
# Desired no barren leaves thy heart doth
# Of love, dare art those the come kind for see
# And beauty's present. Born summer's had gift
# Be slave, I the sorrow, in evil of
#   Next have, will better curse. Bosom more have
#   Much death's now I heart of thee, he age prove

# %%
for i in range(10):
    print_poem(gen_poem(HMM10, obs_map, key_list, n_words=12))
    print("\n")
# Out:
# True respects expire i that what of my,
# Grey and look lovely this the lips and making,
# Under that worth as five sweet an now ride,
# Yet am thy nothing meditation not.
# Be me will in no i determined,
# In gentle head from excuse when but nor,
# Featureless a thy cloud in such goest to,
# One have mine belongs of bear not my joy.
# Prophetic corrupt make my nothing the,
# Fierce thy though are it of vouchsafe arts thou,
# Doth wake that youth should such i walls false bright,
# More all was thence where thy will and there did.
#   Three my thy canopy in nobler you,
#   For now at seeting beseechers and be.
#
#
# Nor tender in me is was summers large,
# New counterpart he have still not mend love,
# Heart ay wantonly and that end an love,
# Ah despised i and others thy waste.
# Tables the glass in his mind becomes her,
# Come doth will hawks in passed blindness they to,
# Still to but wrong not eyes with glance strongly,
# Night to thy true thoughts almost the of hope.
# Find any still that when his story count,
# Is pride do thence her breast loves his own it,
# This me wherewith extreme this lies sick of,
# Recite his surly night heir seest afloat.
#   My executor when thine progress knows,
#   The praise and i and tell bear guess her should.
#
#
# Mayst seconds sense wealth your limbs and cheek i,
# Most is love from then though more main with my,
# Times praise and thou of his slave to bestow,
# Thou appears own stores and straight are sickness.
# A days hast be may travel enjoy oaths,
# Of black praise and more mine dost die ere i,
# Pale i at is old hundred as chide then,
# Play thou art see his face and it and cruel.
# Are my beauty crossed deaths a transgression,
# It beauty for fame and love rightly them,
# Save no groan then when their trespass thou space,
# Which my beauty which as her kind or gift.
#   Your more as poor some to common herald,
#   Love remain i to all what times the love.
#
#
# Self love allege that adverse place part me,
# Have leisure numbers lusty so do fair,
# How from his undivided than lawful,
# Dwell in fault one no messengers not to.
# Celestial hearsay here in one deeds shall,
# Created active and cry my height no,
# The glorious times course it her true that the,
# Anon used for first deep this thyself pleasure.
# If that my darkness dull chips doth on stores,
# Is to die i deeds in eyes i in not,
# Me i flies have sweet love even nothing to,
# Cries doth me to both with antique sweet truth.
#   Stewards strains no holy and give my loves,
#   Who in the in expressed do yet me new.
#
#
# Of the stormy that your lie even fair will,
# Papers since why to others his love of,
# Doth have be him and show certain mine in,
# Sail so as and those of doom from my deeds.
# In the love of reign the on black repair,
# Crooked when swear plea edge mother not leads,
# Of thy perpetual hour erred subtleties,
# To chest well cast my night another i.
# Comes be esteemed still hast that worth that to,
# Refuse ransom thee cruel forth near taken,
# And so mayst thou draw thy stars unless night,
# Not gift are outright send leaves death vial.
#   Such tomb was thee not thee you my name in,
#   To me ill out brow shalt true of monsters.
#
#
# To thy hope beauty to all own which eyes,
# A rents thence bewailed flower is use ear,
# You from thou maladies a alchemy,
# Of the tempests it in an sober in.
# Proud the glory are show rare in day most,
# Were not are hard seen and fair i within,
# As no fair honey the my devise of,
# One of resembling both that his such lived.
# Stealth i are hear concord from of head i,
# Having says to all sequent phoenix best,
# Thief power do me i upon a good i,
# Then do bring are so look mine what did loving.
#   Calls that shown to death alone to mine treason,
#   Time upon thou still covetous in that.
#
#
# Of soon pluck keep methods his summer that,
# I then drooping my sins thou enfeebled,
# Would have thee perspective thou bequest i,
# A wear night will thrive lose hearts and belong.
# And that tongues new defendant loves wish thou,
# Who will thee methods be by his audit,
# Speaking for his friend as not so well with,
# He this the save of will legacy might.
# Like thy winter when whose receipt to so,
# Forwards gone upon the brings to is far,
# Glazed think i to come but your tract terms,
# Being i not me off beggared in with their.
#   Pitch for beauteous form and restful brain in,
#   Or free for the my glory when summers.
#
#
# Dost privilege the my least hold friend i,
# The sight blooms errors swear can stand give them,
# Kiss but night to more here shalt show we and,
# Upon takes to have thee and look eyes shall.
# To but thy use fortune within the truth,
# Cunning write or level other my our,
# That beauty fight in heavenly save art me,
# From my level with tongues have love by that.
# Every think the no striving proud by i,
# Even this to me more sick churls reason now,
# Such that ages deceivest fire may her,
# False her might hate of when thou stained from such.
#   Saint and foul to me this thou it her head,
#   That springs then cold mutual bastard i i.
#
#
# Man at imperfect deceased and but,
# Beside on are change vilest thence is ah,
# Interest virtuous me they water writ to,
# Nor this lines be not with shame in i to.
# Besiege i to land with thou of thy with,
# Although my all not misplaced child done nor,
# Speak mend that thy for fairest one things and,
# In forty my rose every thou had thy.
# Muse thy penance place that will privilage,
# Loves eye me wilt me write his singleness,
# But made be mine in perfection oaths doth,
# I can ride hath to destroys that mind keeps.
#   Assemble bases but of gaudy muse,
#   But and being to record hear make therefore.
#
#
# Night him gives but of created do thus,
# If know my lusty yet within only,
# Alchemy then be might most may bad be,
# Me can but fears never astronomy.
# Of intelligence wrinkles heed i spoils,
# Play by eyes to yet hath love to by which,
# Why remembered beauteous flattery in i,
# Dare teachest be which to be men not have.
# Is still him mine boat my rose unmoved,
# Me such breath double your every love not,
# Me thy style thou to is accuse assailed,
# Tired see yet their miracle dost which can.
#   Deep hast than what to dost doting desire,
#   If seest his feeling that over shall till.
